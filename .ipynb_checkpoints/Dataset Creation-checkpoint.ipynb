# %%
import pandas as pd
import unidecode

# %%
drivers = pd.read_csv('dataset/drivers.csv')
races = pd.read_csv('dataset/races.csv')
teams = pd.read_csv('dataset/constructors.csv')
race_results = pd.read_csv('dataset/results.csv')
circuit_info = pd.read_csv('dataset/circuits.csv')
circuit_info = circuit_info[['circuitId', 'lat', 'lng']]


driver_race_results = pd.merge(race_results, drivers, on="driverId")
driver_race_results['driver_name'] = driver_race_results[['forename', 'surname']].apply(lambda x: unidecode.unidecode(' '.join(x)), axis=1)
driver_race_results = pd.merge(driver_race_results, races, on='raceId')
driver_race_results = pd.merge(driver_race_results, teams, on='constructorId')
driver_race_results = pd.merge(driver_race_results, circuit_info, on='circuitId')
driver_race_results.drop(['number_x', 'time_x', 'milliseconds', 'fastestLap', 'rank', 'statusId','number_y','code','url_x', 'url_y', 'time_y', 'url', 'forename', 'surname'], axis=1, inplace=True)
driver_race_results.rename(columns={'lng':'lon','grid': 'start_position', 'positionOrder': 'finish_position','nationality_x':'driver_nationality', 'nationality_y':'team_nationality', 'year':'race_year', 'name_x':'circuit_name', 'name_y':'team_name'}, inplace=True)
driver_race_results.sort_values('resultId', inplace=True)
driver_race_results.to_csv("race_results_mega.csv", index=False)

# %%
df = pd.read_csv('race_results_mega.csv')
df
# Out:
#        resultId  raceId  driverId  constructorId  start_position position  \
# 0             1      18         1              1               1        1
# 1             2      18         2              2               5        2
# 2             3      18         3              3               7        3
# 3             4      18         4              4              11        4
# 4             5      18         5              1               3        5
# ...         ...     ...       ...            ...             ...      ...
# 25135     25141    1060       849              3              18       16
# 25136     25142    1060        20            117              11       17
# 25137     25143    1060       854            210              19       18
# 25138     25144    1060       853            210              20       19
# 25139     25145    1060       839            214              17       \N
#
#        finish_position  points  laps fastestLapTime  ... race_year round  \
# 0                    1    10.0    58       1:27.452  ...      2008     1
# 1                    2     8.0    58       1:27.739  ...      2008     1
# 2                    3     6.0    58       1:28.090  ...      2008     1
# 3                    4     5.0    58       1:28.603  ...      2008     1
# 4                    5     4.0    58       1:27.418  ...      2008     1
# ...                ...     ...   ...            ...  ...       ...   ...
# 25135               16     0.0    70       1:08.520  ...      2021     9
# 25136               17     0.0    69       1:08.420  ...      2021     9
# 25137               18     0.0    69       1:09.394  ...      2021     9
# 25138               19     0.0    69       1:09.757  ...      2021     9
# 25139               20     0.0     0             \N  ...      2021     9
#
#       circuitId           circuit_name        date  constructorRef  \
# 0             1  Australian Grand Prix  2008-03-16         mclaren
# 1             1  Australian Grand Prix  2008-03-16      bmw_sauber
# 2             1  Australian Grand Prix  2008-03-16        williams
# 3             1  Australian Grand Prix  2008-03-16         renault
# 4             1  Australian Grand Prix  2008-03-16         mclaren
# ...         ...                    ...         ...             ...
# 25135        70    Austrian Grand Prix  2021-07-04        williams
# 25136        70    Austrian Grand Prix  2021-07-04    aston_martin
# 25137        70    Austrian Grand Prix  2021-07-04            haas
# 25138        70    Austrian Grand Prix  2021-07-04            haas
# 25139        70    Austrian Grand Prix  2021-07-04          alpine
#
#             team_name  team_nationality      lat       lon
# 0             McLaren           British -37.8497  144.9680
# 1          BMW Sauber            German -37.8497  144.9680
# 2            Williams           British -37.8497  144.9680
# 3             Renault            French -37.8497  144.9680
# 4             McLaren           British -37.8497  144.9680
# ...               ...               ...      ...       ...
# 25135        Williams           British  47.2197   14.7647
# 25136    Aston Martin           British  47.2197   14.7647
# 25137    Haas F1 Team          American  47.2197   14.7647
# 25138    Haas F1 Team          American  47.2197   14.7647
# 25139  Alpine F1 Team            French  47.2197   14.7647
#
# [25140 rows x 25 columns]

# %%
df[df.finish_position== 1].driver_name.value_counts()
# Out:
# Lewis Hamilton        98
# Michael Schumacher    91
# Sebastian Vettel      53
# Alain Prost           51
# Ayrton Senna          41
#                       ..
# Jimmy Bryan            1
# Carlos Pace            1
# Gunnar Nilsson         1
# Sam Hanks              1
# Vittorio Brambilla     1
# Name: driver_name, Length: 110, dtype: int64

# %%
# pd.read_csv('dataset/circuits.csv').columns
# %ls -ltr dataset
df.columns
# Out:
# Index(['resultId', 'raceId', 'driverId', 'constructorId', 'start_position',
#        'positionOrder', 'points', 'laps', 'fastestLapTime', 'fastestLapSpeed',
#        'driverRef', 'dob', 'driver_nationality', 'driver_name', 'race_year',
#        'round', 'circuitId', 'circuit_name', 'date', 'constructorRef',
#        'team_name', 'team_nationality', 'lat', 'lon'],
#       dtype='object')

# %%
df[(df.driver_name == "Lewis Hamilton")]['position'].value_counts()
# Out:
# 1     98
# 2     43
# 3     30
# \N    24
# 4     22
# 5     19
# 7     10
# 6      6
# 9      6
# 12     4
# 8      4
# 10     2
# 13     2
# 16     1
# 18     1
# 14     1
# 19     1
# 15     1
# Name: position, dtype: int64
