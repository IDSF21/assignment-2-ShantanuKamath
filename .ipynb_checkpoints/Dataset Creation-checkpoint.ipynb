# %%
import pandas as pd
import unidecode

# %%
drivers = pd.read_csv('dataset/drivers.csv')
races = pd.read_csv('dataset/races.csv')
teams = pd.read_csv('dataset/constructors.csv')
race_results = pd.read_csv('dataset/results.csv')
circuit_info = pd.read_csv('dataset/circuits.csv')
circuit_info = circuit_info[['circuitId', 'lat', 'lng']]


driver_race_results = pd.merge(race_results, drivers, on="driverId")
driver_race_results['driver_name'] = driver_race_results[['forename', 'surname']].apply(lambda x: unidecode.unidecode(' '.join(x)), axis=1)
driver_race_results = pd.merge(driver_race_results, races, on='raceId')
driver_race_results = pd.merge(driver_race_results, teams, on='constructorId')
driver_race_results = pd.merge(driver_race_results, circuit_info, on='circuitId')
driver_race_results.drop(['number_x', 'positionText', 'position', 'time_x', 'milliseconds', 'fastestLap', 'rank', 'statusId','number_y','code','url_x', 'url_y', 'time_y', 'url', 'forename', 'surname'], axis=1, inplace=True)
driver_race_results.rename(columns={'lng':'lon','grid': 'start_position', 'positionOrder': 'finish_position','nationality_x':'driver_nationality', 'nationality_y':'team_nationality', 'year':'race_year', 'name_x':'circuit_name', 'name_y':'team_name'}, inplace=True)
driver_race_results.sort_values('resultId', inplace=True)
driver_race_results.to_csv("race_results_mega.csv", index=False)

# %%
df = pd.read_csv('race_results_mega.csv')
df
# Out:
#        resultId  raceId  driverId  constructorId  start_position  \
# 0             1      18         1              1               1
# 1             2      18         2              2               5
# 2             3      18         3              3               7
# 3             4      18         4              4              11
# 4             5      18         5              1               3
# ...         ...     ...       ...            ...             ...
# 25135     25141    1060       849              3              18
# 25136     25142    1060        20            117              11
# 25137     25143    1060       854            210              19
# 25138     25144    1060       853            210              20
# 25139     25145    1060       839            214              17
#
#        finish_position  points  laps fastestLapTime fastestLapSpeed  ...  \
# 0                    1    10.0    58       1:27.452         218.300  ...
# 1                    2     8.0    58       1:27.739         217.586  ...
# 2                    3     6.0    58       1:28.090         216.719  ...
# 3                    4     5.0    58       1:28.603         215.464  ...
# 4                    5     4.0    58       1:27.418         218.385  ...
# ...                ...     ...   ...            ...             ...  ...
# 25135               16     0.0    70       1:08.520         226.865  ...
# 25136               17     0.0    69       1:08.420         227.196  ...
# 25137               18     0.0    69       1:09.394         224.007  ...
# 25138               19     0.0    69       1:09.757         222.842  ...
# 25139               20     0.0     0             \N              \N  ...
#
#       race_year round circuitId           circuit_name        date  \
# 0          2008     1         1  Australian Grand Prix  2008-03-16
# 1          2008     1         1  Australian Grand Prix  2008-03-16
# 2          2008     1         1  Australian Grand Prix  2008-03-16
# 3          2008     1         1  Australian Grand Prix  2008-03-16
# 4          2008     1         1  Australian Grand Prix  2008-03-16
# ...         ...   ...       ...                    ...         ...
# 25135      2021     9        70    Austrian Grand Prix  2021-07-04
# 25136      2021     9        70    Austrian Grand Prix  2021-07-04
# 25137      2021     9        70    Austrian Grand Prix  2021-07-04
# 25138      2021     9        70    Austrian Grand Prix  2021-07-04
# 25139      2021     9        70    Austrian Grand Prix  2021-07-04
#
#        constructorRef       team_name team_nationality      lat       lon
# 0             mclaren         McLaren          British -37.8497  144.9680
# 1          bmw_sauber      BMW Sauber           German -37.8497  144.9680
# 2            williams        Williams          British -37.8497  144.9680
# 3             renault         Renault           French -37.8497  144.9680
# 4             mclaren         McLaren          British -37.8497  144.9680
# ...               ...             ...              ...      ...       ...
# 25135        williams        Williams          British  47.2197   14.7647
# 25136    aston_martin    Aston Martin          British  47.2197   14.7647
# 25137            haas    Haas F1 Team         American  47.2197   14.7647
# 25138            haas    Haas F1 Team         American  47.2197   14.7647
# 25139          alpine  Alpine F1 Team           French  47.2197   14.7647
#
# [25140 rows x 24 columns]

# %%
df[df.finish_position== 1].driver_name.value_counts()
# Out:
# Lewis Hamilton        98
# Michael Schumacher    91
# Sebastian Vettel      53
# Alain Prost           51
# Ayrton Senna          41
#                       ..
# Jimmy Bryan            1
# Carlos Pace            1
# Gunnar Nilsson         1
# Sam Hanks              1
# Vittorio Brambilla     1
# Name: driver_name, Length: 110, dtype: int64

# %%
# pd.read_csv('dataset/circuits.csv').columns
# %ls -ltr dataset
df.columns
# Out:
# Index(['resultId', 'raceId', 'driverId', 'constructorId', 'start_position',
#        'finish_position', 'points', 'laps', 'fastestLapTime',
#        'fastestLapSpeed', 'driverRef', 'dob', 'driver_nationality',
#        'driver_name', 'race_year', 'round', 'circuitId', 'circuit_name',
#        'date', 'constructorRef', 'team_name', 'team_nationality', 'lat',
#        'lon'],
#       dtype='object')

# %%
driverdf = df[(df.driver_name.isin(['Lewis Hamilton', 'Michael Schumacher', 'Nico Rosberg', 'Kimi Raikkonen', 'Fernando Alonso']))]
driverdf.groupby(['circuit_name', 'driver_name']).agg("count")
df['circuit_name'].unique()
# Out:
# array(['Australian Grand Prix', 'Malaysian Grand Prix',
#        'Bahrain Grand Prix', 'Spanish Grand Prix', 'Turkish Grand Prix',
#        'Monaco Grand Prix', 'Canadian Grand Prix', 'French Grand Prix',
#        'British Grand Prix', 'German Grand Prix', 'Hungarian Grand Prix',
#        'European Grand Prix', 'Belgian Grand Prix', 'Italian Grand Prix',
#        'Singapore Grand Prix', 'Japanese Grand Prix',
#        'Chinese Grand Prix', 'Brazilian Grand Prix',
#        'United States Grand Prix', 'San Marino Grand Prix',
#        'Austrian Grand Prix', 'Argentine Grand Prix',
#        'Luxembourg Grand Prix', 'Portuguese Grand Prix',
#        'Pacific Grand Prix', 'South African Grand Prix',
#        'Mexican Grand Prix', 'Detroit Grand Prix', 'Dutch Grand Prix',
#        'Dallas Grand Prix', 'United States Grand Prix West',
#        'Swiss Grand Prix', 'Caesars Palace Grand Prix',
#        'Swedish Grand Prix', 'Abu Dhabi Grand Prix', 'Indianapolis 500',
#        'Moroccan Grand Prix', 'Pescara Grand Prix', 'Korean Grand Prix',
#        'Indian Grand Prix', 'Russian Grand Prix', 'Azerbaijan Grand Prix',
#        'Styrian Grand Prix', '70th Anniversary Grand Prix',
#        'Tuscan Grand Prix', 'Eifel Grand Prix',
#        'Emilia Romagna Grand Prix', 'Sakhir Grand Prix'], dtype=object)

# %%
circuits_latlngs = df.groupby(['circuit_name'], as_index = False)['lat', 'lon'].first()
circuits_latlngs
# Out:
# /var/folders/cc/y1qgj6_s14161c19gcl8_3fh0000gn/T/ipykernel_62364/2998123161.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   circuits_latlngs = df.groupby(['circuit_name'], as_index = False)['lat', 'lon'].first()
#                      circuit_name       lat         lon
# 0     70th Anniversary Grand Prix  52.07860   -1.016940
# 1            Abu Dhabi Grand Prix  24.46720   54.603100
# 2            Argentine Grand Prix -34.69430  -58.459300
# 3           Australian Grand Prix -37.84970  144.968000
# 4             Austrian Grand Prix  47.21970   14.764700
# 5           Azerbaijan Grand Prix  40.37250   49.853300
# 6              Bahrain Grand Prix  26.03250   50.510600
# 7              Belgian Grand Prix  50.43720    5.971390
# 8            Brazilian Grand Prix -23.70360  -46.699700
# 9              British Grand Prix  52.07860   -1.016940
# 10      Caesars Palace Grand Prix  36.11620 -115.174000
# 11            Canadian Grand Prix  45.50000  -73.522800
# 12             Chinese Grand Prix  31.33890  121.220000
# 13              Dallas Grand Prix  32.77740  -96.758700
# 14             Detroit Grand Prix  42.32980  -83.040100
# 15               Dutch Grand Prix  52.38880    4.540920
# 16               Eifel Grand Prix  50.33560    6.947500
# 17      Emilia Romagna Grand Prix  44.34390   11.716700
# 18            European Grand Prix  39.45890   -0.331667
# 19              French Grand Prix  46.86420    3.163610
# 20              German Grand Prix  49.32780    8.565830
# 21           Hungarian Grand Prix  47.57890   19.248600
# 22              Indian Grand Prix  28.34870   77.533100
# 23               Indianapolis 500  39.79500  -86.234700
# 24             Italian Grand Prix  45.61560    9.281110
# 25            Japanese Grand Prix  35.37170  138.927000
# 26              Korean Grand Prix  34.73330  126.417000
# 27          Luxembourg Grand Prix  50.33560    6.947500
# 28           Malaysian Grand Prix   2.76083  101.738000
# 29             Mexican Grand Prix  19.40420  -99.090700
# 30              Monaco Grand Prix  43.73470    7.420560
# 31            Moroccan Grand Prix  33.57860   -7.687500
# 32             Pacific Grand Prix  34.91500  134.221000
# 33             Pescara Grand Prix  42.47500   14.150800
# 34          Portuguese Grand Prix  38.75060   -9.394170
# 35             Russian Grand Prix  43.40570   39.957800
# 36              Sakhir Grand Prix  26.03250   50.510600
# 37          San Marino Grand Prix  44.34390   11.716700
# 38           Singapore Grand Prix   1.29140  103.864000
# 39       South African Grand Prix -25.98940   28.076700
# 40             Spanish Grand Prix  41.57000    2.261110
# 41             Styrian Grand Prix  47.21970   14.764700
# 42             Swedish Grand Prix  57.26530   13.604200
# 43               Swiss Grand Prix  47.36250    4.899130
# 44             Turkish Grand Prix  40.95170   29.405000
# 45              Tuscan Grand Prix  43.99750   11.371900
# 46       United States Grand Prix  39.79500  -86.234700
# 47  United States Grand Prix West  33.76510 -118.189000

# %%
circuits_latlngs = df.groupby(['circuit_name'], as_index=False)['lat', 'lon'].first()
circuit = "Spanish Grand Prix"
lat = circuits_latlngs[circuits_latlngs.circuit_name == circuit].lat.iloc[0]
lon = circuits_latlngs[circuits_latlngs.circuit_name == circuit].lon.iloc[0]
print(lat, lon)
# Out:
# 41.57 2.26111
# /var/folders/cc/y1qgj6_s14161c19gcl8_3fh0000gn/T/ipykernel_62364/1330595758.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   circuits_latlngs = df.groupby(['circuit_name'], as_index=False)['lat', 'lon'].first()

# %%
data= df
driver_data = data[(data.driver_name == "Michael Schumacher")]
data2 = driver_data[driver_data.circuit_name == circuit].set_index('race_year')
data2[['start_position', 'finish_position']]
data2[data2.index == data2.index[-1]]['points'].mean()
# Out:
# 0.0

# %%
driver = data[(data.driver_name == "Michael Schumacher")]
driver[(driver.race_year == driver.race_year.max())].iloc[0]['team_name']
# Out:
# 'Mercedes'

# %%
df = df[df.race_year.between(2000, 2021, inclusive='both')]
# Out:
# /var/folders/cc/y1qgj6_s14161c19gcl8_3fh0000gn/T/ipykernel_62364/1895573028.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df = df[df.race_year.between(2000, 2021, inclusive=True)]
